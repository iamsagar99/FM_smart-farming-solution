# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from io import StringIO

# %%
df = pd.read_csv(f"D:\AI Fellowship Fusemachine\FM_smart-farming-solution\data\CAF_Sensor_Dataset_2\caf_sensors\Daily\CAF007.txt", sep='\t')

# %%
df.isna().su
# Out:
# Location       0
# Date           0
# VW_30cm     1575
# VW_60cm     1931
# VW_90cm     1429
# VW_120cm    1413
# VW_150cm    1480
# T_30cm      1563
# T_60cm      1413
# T_90cm      1429
# T_120cm     1413
# T_150cm     1726
# dtype: int64

# %%
df.shape
# Out:
# (3346, 12)

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df_clean = df.dropna()

# %%
df_clean.shape
# Out:
# (1123, 12)

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.select_dtypes(exclude='O').corr().iloc[:5,5:], annot=True)
# Out:
# <Axes: >

# %%
df.select_dtypes(exclude='O').corr().iloc[:5,5:]
# Out:
#             T_30cm    T_60cm    T_90cm   T_120cm   T_150cm
# VW_30cm  -0.578027 -0.652634 -0.720317 -0.792073 -0.648597
# VW_60cm  -0.250068 -0.339706 -0.439958 -0.577862 -0.420458
# VW_90cm  -0.137557 -0.259572 -0.372954 -0.487797 -0.418011
# VW_120cm  0.140392  0.047039 -0.027922 -0.169683 -0.129482
# VW_150cm  0.033401 -0.026716 -0.085201 -0.273787 -0.402481
